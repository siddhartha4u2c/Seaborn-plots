# %%
# Carried out as part of curriculum at Great learning
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("honeyproduction.csv")

# %%
df.head(10)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
# 5    FL  230000.0           98  22540000.0   4508000.0        0.64
# 6    GA   75000.0           56   4200000.0    307000.0        0.69
# 7    HI    8000.0          118    944000.0     66000.0        0.77
# 8    ID  120000.0           50   6000000.0   2220000.0        0.65
# 9    IL    9000.0           71    639000.0    204000.0        1.19
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998
# 5  14426000.0  1998
# 6   2898000.0  1998
# 7    727000.0  1998
# 8   3900000.0  1998
# ...

# %%
df.describe().T
# Out:
#              count          mean           std        min          25%  \
# numcol       626.0  6.028435e+04  9.107709e+04    2000.00    9000.0000
# yieldpercol  626.0  6.200958e+01  1.945875e+01      19.00      48.0000
# totalprod    626.0  4.169086e+06  6.883847e+06   84000.00  475000.0000
# stocks       626.0  1.318859e+06  2.272964e+06    8000.00  143000.0000
# priceperlb   626.0  1.409569e+00  6.385989e-01       0.49       0.9325
# prodvalue    626.0  4.715741e+06  7.976110e+06  162000.00  759250.0000
# year         626.0  2.004864e+03  4.317306e+00    1998.00    2001.0000
#
#                     50%         75%          max
# numcol         26000.00    63750.00    510000.00
# yieldpercol       60.00       74.00       136.00
# totalprod    1533000.00  4175250.00  46410000.00
# stocks        439500.00  1489500.00  13800000.00
# priceperlb         1.36        1.68         4.15
# prodvalue    1841500.00  4703250.00  69615000.00
# year            2005.00     2009.00      2012.00

# %%
df.describe(include='all').T
# Out:
#             count unique  top freq         mean          std     min     25%  \
# state         626     44   ID   15          NaN          NaN     NaN     NaN
# numcol        626    NaN  NaN  NaN      60284.3      91077.1    2000    9000
# yieldpercol   626    NaN  NaN  NaN      62.0096      19.4588      19      48
# totalprod     626    NaN  NaN  NaN  4.16909e+06  6.88385e+06   84000  475000
# stocks        626    NaN  NaN  NaN  1.31886e+06  2.27296e+06    8000  143000
# priceperlb    626    NaN  NaN  NaN      1.40957     0.638599    0.49  0.9325
# prodvalue     626    NaN  NaN  NaN  4.71574e+06  7.97611e+06  162000  759250
# year          626    NaN  NaN  NaN      2004.86      4.31731    1998    2001
#
#                     50%          75%         max
# state               NaN          NaN         NaN
# numcol            26000        63750      510000
# yieldpercol          60           74         136
# totalprod     1.533e+06  4.17525e+06   4.641e+07
# ...

# %%
df['state'].nunique()
# Out:
# 44

# %%
df['state'].unique()
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN',
#        'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MI', 'MN', 'MS', 'MO', 'MT',
#        'NE', 'NV', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA',
#        'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'SC'],
#       dtype=object)

# %%
df['state'].value_counts()
# Out:
# ID    15
# NY    15
# MS    15
# NE    15
# TN    15
# SD    15
# ND    15
# UT    15
# MI    15
# MO    15
# VA    15
# LA    15
# KY    15
# HI    15
# MN    15
# NM    15
# FL    15
# CA    15
# NJ    15
# TX    15
# OH    15
# PA    15
# KS    15
# VT    15
# AZ    15
# WA    15
# AL    15
# NC    15
# CO    15
# GA    15
# IL    15
# WV    15
# WI    15
# IN    15
# IA    15
# MT    15
# AR    15
# WY    15
# OR    15
# ME    15
# NV    11
# MD     6
# OK     6
# SC     3
# Name: state, dtype: int64

# %%
df[['state','totalprod']].groupby('state').mean().round()
# Out:
#         totalprod
# state
# AL       825467.0
# AR      2810400.0
# AZ      2032267.0
# CA     23169000.0
# CO      1750600.0
# FL     16469867.0
# GA      3299933.0
# HI       843133.0
# IA      2080000.0
# ID      4410667.0
# IL       498333.0
# IN       484000.0
# KS       707933.0
# KY       229667.0
# LA      3627333.0
# MD       211000.0
# ME       246733.0
# MI      4854667.0
# MN      9624000.0
# MO       871533.0
# MS      1456867.0
# MT     10437467.0
# NC       542733.0
# ND     31672333.0
# NE      3158600.0
# NJ       399533.0
# NM       476467.0
# NV       439273.0
# NY      3937467.0
# OH      1040067.0
# OK       201167.0
# OR      2121400.0
# PA      1295600.0
# SC       343333.0
# SD     17742733.0
# TN       407733.0
# TX      6993600.0
# UT      1179067.0
# VA       266533.0
# VT       388067.0
# WA      2687733.0
# WI      5455533.0
# WV       321200.0
# WY      2617933.0

# %%
df[['year','yieldpercol']].groupby('year').mean().round()
# Out:
#       yieldpercol
# year
# 1998         70.0
# 1999         65.0
# 2000         68.0
# 2001         65.0
# 2002         67.0
# 2003         63.0
# 2004         65.0
# 2005         64.0
# 2006         62.0
# 2007         59.0
# 2008         61.0
# 2009         54.0
# 2010         56.0
# 2011         55.0
# 2012         55.0

# %%
sns.pairplot(df[['numcol','yieldpercol','stocks','priceperlb','prodvalue']])

# %%
cor=df[['numcol','yieldpercol','totalprod','stocks','priceperlb','prodvalue']].corr()

# %%
sns.heatmap(cor,annot=True,cmap='plasma',vmin=-1,vmax=1)

# %%
sns.pointplot(df['year'],df['totalprod'])

# %%
g=sns.FacetGrid(df,col="state",col_wrap=5,height=5)
g=g.map(plt.plot,"year","totalprod",marker=".")

# %%
sns.lmplot(x='numcol',y='prodvalue',data=df)

# %%
sns.lmplot(x='numcol',y='prodvalue',data=df,hue='state')

# %%
sns.lmplot(x='numcol',y='prodvalue',data=df,hue='year')

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.boxplot('year','totalprod',data=df)

# %%
sns.pointplot(df['year'],df['prodvalue'])

# %%
sns.lmplot(x='totalprod',y='prodvalue',data=df)
